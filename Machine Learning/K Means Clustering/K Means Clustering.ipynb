# %% [markdown]
# # K Means Clustering
# (Adopted from Udemy Course, *Python for Data Science and Machine Learning Bootcamp* by Jose Portilla)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\Dell\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Dell\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\Dell\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# ### Create some fake data

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1, random_state = 0)

# %%
sns.set_style("darkgrid")
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap = "rainbow", edgecolors="black")

# %% [markdown]
# ### K Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-1.90317099,  2.9957545 ],
#        [-1.37860109,  7.59103386],
#        [ 2.09071191,  1.00770612],
#        [ 0.87599329,  4.21437989]])

# %%
kmeans.labels_
# Out:
# array([2, 0, 3, 1, 2, 3, 0, 3, 3, 3, 3, 2, 0, 0, 2, 3, 1, 1, 1, 3, 1, 3,
#        2, 0, 2, 2, 1, 2, 2, 3, 1, 3, 0, 2, 0, 3, 0, 3, 3, 1, 1, 1, 1, 3,
#        2, 0, 3, 1, 1, 3, 1, 0, 0, 1, 2, 1, 0, 2, 1, 2, 1, 3, 2, 3, 1, 3,
#        2, 1, 0, 0, 2, 2, 3, 3, 0, 1, 0, 0, 2, 2, 1, 3, 2, 2, 0, 3, 3, 2,
#        0, 0, 1, 1, 1, 3, 3, 2, 0, 1, 2, 3, 1, 2, 2, 1, 1, 0, 3, 2, 2, 3,
#        1, 0, 0, 2, 2, 3, 2, 0, 1, 3, 1, 0, 3, 2, 3, 0, 3, 0, 2, 3, 0, 2,
#        3, 1, 1, 0, 1, 1, 2, 1, 2, 0, 2, 2, 0, 2, 3, 2, 0, 1, 1, 1, 3, 0,
#        2, 3, 1, 0, 1, 2, 1, 2, 2, 0, 0, 1, 3, 2, 2, 0, 3, 3, 0, 1, 1, 1,
#        3, 1, 0, 0, 3, 2, 3, 2, 3, 0, 0, 1, 3, 1, 2, 2, 3, 1, 0, 0, 0, 3,
#        1, 3])

# %%
f, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize = (10,6))
ax1.set_title("K Means")
ax1.scatter(data[0][:,0], data[0][:,1], c = kmeans.labels_, cmap = "rainbow", edgecolor = "black")
ax2.set_title("Original")
ax2.scatter(data[0][:,0], data[0][:,1], c = data[1], cmap="rainbow", edgecolor = "black")
