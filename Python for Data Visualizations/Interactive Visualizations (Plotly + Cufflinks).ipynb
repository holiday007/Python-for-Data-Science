# %% [markdown]
# # Interactive Visualizations - Plotly & Cufflinks
# (Adopted from Udemy Course, *Python for Data Science and Machine Learning Bootcamp* by Jose Portilla)

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
# set up plotly

# check version, require > 1.9.0
from plotly import __version__
print(__version__)
# Out:
# 4.4.1

# %%
# set up
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf

# for notebooks
init_notebook_mode(connected=True)

# for offline use
cf.go_offlineline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %% [markdown]
# **Fake Data**

# %%
df = pd.DataFrame(np.random.randn(100,4), columns = "A B C D".split())
df.head()
# Out:
#           A         B         C         D
# 0  0.962376 -0.664492 -0.459906 -0.623217
# 1  0.661024 -1.280414  0.912617 -1.603115
# 2 -0.367982 -1.181819 -1.818285 -1.365128
# 3  1.290553 -0.775926 -0.006518  0.691746
# 4 -0.217343  0.248679  0.504443 -0.302149

# %%
df2 = pd.DataFrame({"category":["A", "B","C"], "values":[32,43,50]})
df2
# Out:
#   category  values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# **LinePlot**

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="cd68ce33-4ce3-42bf-bd0f-769245fc9834" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cd68ce33-4ce3-42bf-bd0f-769245fc9834")) {
#                     Plotly.newPlot(
#                         'cd68ce33-4ce3-42bf-bd0f-769245fc9834',
# ...

# %% [markdown]
# **Scatter Plot**

# %%
# "mode" - otherwise it will be crazy line plot
# "size"
df.iplot(kind = "scatter", x = "A", y="B", mode = "markers", size = 15)
# Out:
# <div>
#
#
#             <div id="133aaefd-84b1-4497-8b9a-613acc33d4b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("133aaefd-84b1-4497-8b9a-613acc33d4b6")) {
#                     Plotly.newPlot(
#                         '133aaefd-84b1-4497-8b9a-613acc33d4b6',
# ...

# %% [markdown]
# **Bar Plots**

# %%
df2.iplot(kind="bar", x="category", y="values")
# Out:
# <div>
#
#
#             <div id="f0416db0-9200-48af-a8b7-1a5697aea08c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f0416db0-9200-48af-a8b7-1a5697aea08c")) {
#                     Plotly.newPlot(
#                         'f0416db0-9200-48af-a8b7-1a5697aea08c',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.sum().iplot(kind = "bar") # use aggregate function
# Out:
# <div>
#
#
#             <div id="9612327a-058d-4f8c-888d-20692fb9cf8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9612327a-058d-4f8c-888d-20692fb9cf8b")) {
#                     Plotly.newPlot(
#                         '9612327a-058d-4f8c-888d-20692fb9cf8b',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [-13.116666735617889, 1.3573187550026535, 10.176620560378161, 19.474737433716406]}],
# ...

# %% [markdown]
# **Box Plot**

# %%
df.iplot(kind="box")
# Out:
# <div>
#
#
#             <div id="afdff22b-6dd0-4c04-9893-2bb88752eeb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("afdff22b-6dd0-4c04-9893-2bb88752eeb7")) {
#                     Plotly.newPlot(
#                         'afdff22b-6dd0-4c04-9893-2bb88752eeb7',
# ...

# %% [markdown]
# **3D Surface**

# %%
df3 = pd.DataFrame({"x":[1,2,3,4,5], "y":[10,20,30,20,10], "z":[5,4,3,2,1]})
df3.iplot(kind = "surface", colorscale = "rdylbu")
# Out:
# <div>
#
#
#             <div id="c1429477-cc19-4318-8290-51c9a3a9b193" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c1429477-cc19-4318-8290-51c9a3a9b193")) {
#                     Plotly.newPlot(
#                         'c1429477-cc19-4318-8290-51c9a3a9b193',
# ...

# %% [markdown]
# **Spread**

# %%
df[["A","B"]].iplot(kind = "spread")
# Out:
# <div>
#
#
#             <div id="6f945f0e-698d-4a96-8dd4-1962af5066ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6f945f0e-698d-4a96-8dd4-1962af5066ae")) {
#                     Plotly.newPlot(
#                         '6f945f0e-698d-4a96-8dd4-1962af5066ae',
# ...

# %% [markdown]
# Interpretation
#     - Spread: difference between a & b, a - b

# %% [markdown]
# **Histogram**

# %%
df["A"].iplot(kind = "hist", bins = 25)
# Out:
# <div>
#
#
#             <div id="ac4bf725-f07e-4867-96e9-6b5c5df67487" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ac4bf725-f07e-4867-96e9-6b5c5df67487")) {
#                     Plotly.newPlot(
#                         'ac4bf725-f07e-4867-96e9-6b5c5df67487',
# ...

# %% [markdown]
# **Bubble Plot**

# %%
df.iplot(kind = "bubble", x="A", y="B", size="C")
# Out:
# <div>
#
#
#             <div id="b3086824-b306-4562-89b9-b8195262e093" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b3086824-b306-4562-89b9-b8195262e093")) {
#                     Plotly.newPlot(
#                         'b3086824-b306-4562-89b9-b8195262e093',
# ...

# %% [markdown]
# **Pair-wise Scatter Plot**

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="043633a0-e3ba-4ba3-879a-df37b767426d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("043633a0-e3ba-4ba3-879a-df37b767426d")) {
#                     Plotly.newPlot(
#                         '043633a0-e3ba-4ba3-879a-df37b767426d',
# ...

# %% [markdown]
# # For more
#
# https://github.com/santosjorge/cufflinks
